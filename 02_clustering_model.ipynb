# %% [markdown]
# <a href="https://colab.research.google.com/github/karankumarr17/customer_segmentation/blob/main/02_clustering_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Customer Segmentation – Clustering & Model Development
